# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Chong Kah Chun__
#
# Current Occupation: R & D Engineer

# %% [markdown]
# *I am interested in data science is because it provide a way to simplified the data preparation & analysis into creative output. Besides that, expecting better salary package with data science analysis knowledge.*

# %% [markdown]
# ### I will make a simple calculation using Jupyter Notebook

# %%
108*10-(1+125)/12
# Out:
# 1069.5

# %% [markdown]
# *Test 1*
#
# **Test 2**
#
# **_Test 3_**
#
# ~Test 4~
#
# 1. Test 5
#
# * Test 6
#
# (https://www.google.com)
#
# Inline-style:
# ![alt text](https://github.com/adam-p/markdown-here/raw/master/src/common/images/icon48.png "Logo Title Text 1")
#
# Reference-style:
# ![alt text](https://github.com/adam-p/markdown-here/raw/master/src/common/images/icon48.png "Logo Title Text 2")
#
#
#
# Type of Fruit|Price|Source
# ---|---|---|
# Watermelon|100|China
# Apple|1|Korea
# Dragon Fruit|10000|Malaysia
